# %%
import pandas as pd
df = pd.read_excel("Data_Mundial_Final.xls")
df.head()
# Out:
#   Unnamed: 0 IDENTIFICACIÓN                       Unnamed: 2  UBICACIÓN  \
# 0   OBJECTID         CÓDIGO                           NOMBRE       PAÍS
# 1        NaN            NaN                              NaN        NaN
# 2        127    00127-ARG-P             Aconcagua solar farm  Argentina
# 3        129    00129-ARG-G  Altiplano 200 Solar Power Plant  Argentina
# 4        131    00131-ARG-P              Anchoris solar farm  Argentina
#
#      Unnamed: 4  Unnamed: 5  Unnamed: 6    TERRENO  Unnamed: 8 Unnamed: 9  \
# 0        ESTADO    LONGITUD     LATITUD  ELEVACIÓN        ÁREA     TAMAÑO
# 1           NaN  Grados (°)  Grados (°)       msnm         m^2        NaN
# 2     announced    -68.8713  -32.998501        929  250.337006    Pequeña
# 3     operating  -66.895798    -24.1392       4000     4397290     Grande
# 4  construction  -68.915001  -33.330101        937  645.163025    Pequeña
#
#    ...         Unnamed: 19     Unnamed: 20           Unnamed: 21  \
# ...
